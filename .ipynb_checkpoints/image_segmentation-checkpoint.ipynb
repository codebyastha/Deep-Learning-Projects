# %%
# Deep learning Image Segmentation with U-Net Includes Roc Curve and Precision-Recall curve visualize

# %%
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.gridspec as gridspec
from matplotlib.colors import LinearSegmentedColormap
import warnings
warnings.filterwarnings('ignore')

# %%
# try importing deep learning frameworks
try:
    import torch
    import torch.nn as nn
    import torch.optim as optim
    from torch.utils.data import Dataset, DataLoader
    import torch.nn.functional as F
    TORCH_AVAILABLE = True
    print("Pytorch available : ", torch.__version__)
except ImportError:
    TORCH_AVAILABLE = False
    print("Pytorch not found ")
# Out:
# Pytorch not found

# %%
# !pip install torch torchvision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\ADMIN\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting torch
#   Downloading torch-2.12.0-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading torchvision-0.27.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: filelock in C:\ProgramData\anaconda3\Lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\ProgramData\anaconda3\Lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools<82 in C:\ProgramData\anaconda3\Lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\ProgramData\anaconda3\Lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in C:\ProgramData\anaconda3\Lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in C:\ProgramData\anaconda3\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\ProgramData\anaconda3\Lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: numpy in C:\ProgramData\anaconda3\Lib\site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\ProgramData\anaconda3\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.12.0-cp313-cp313-win_amd64.whl (123.0 MB)
#    ---------------------------------------- 0.0/123.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/123.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/123.0 MB 3.5 MB/s eta 0:00:35
#     --------------------------------------- 1.6/123.0 MB 3.4 MB/s eta 0:00:36
#     --------------------------------------- 2.4/123.0 MB 3.4 MB/s eta 0:00:36
#    - -------------------------------------- 3.4/123.0 MB 3.6 MB/s eta 0:00:34
#    - -------------------------------------- 3.9/123.0 MB 3.6 MB/s eta 0:00:34
#    - -------------------------------------- 4.7/123.0 MB 3.6 MB/s eta 0:00:34
#    - -------------------------------------- 5.5/123.0 MB 3.6 MB/s eta 0:00:33
#    -- ------------------------------------- 6.3/123.0 MB 3.5 MB/s eta 0:00:33
#    -- ------------------------------------- 7.1/123.0 MB 3.6 MB/s eta 0:00:33
#    -- ------------------------------------- 7.9/123.0 MB 3.6 MB/s eta 0:00:32
#    -- ------------------------------------- 8.4/123.0 MB 3.7 MB/s eta 0:00:32
#    -- ------------------------------------- 9.2/123.0 MB 3.5 MB/s eta 0:00:33
#    --- ------------------------------------ 10.0/123.0 MB 3.6 MB/s eta 0:00:32
#    --- ------------------------------------ 10.7/123.0 MB 3.6 MB/s eta 0:00:32
#    --- ------------------------------------ 11.3/123.0 MB 3.6 MB/s eta 0:00:32
#    --- ------------------------------------ 11.8/123.0 MB 3.5 MB/s eta 0:00:33
#    ---- ----------------------------------- 12.6/123.0 MB 3.5 MB/s eta 0:00:32
#    ---- ----------------------------------- 13.4/123.0 MB 3.5 MB/s eta 0:00:32
#    ---- ----------------------------------- 14.4/123.0 MB 3.5 MB/s eta 0:00:31
#    ---- ----------------------------------- 15.2/123.0 MB 3.6 MB/s eta 0:00:31
#    ----- ---------------------------------- 15.7/123.0 MB 3.5 MB/s eta 0:00:31
#    ----- ---------------------------------- 16.5/123.0 MB 3.5 MB/s eta 0:00:31
#    ----- ---------------------------------- 17.3/123.0 MB 3.5 MB/s eta 0:00:30
#    ----- ---------------------------------- 18.1/123.0 MB 3.5 MB/s eta 0:00:30
#    ------ --------------------------------- 18.6/123.0 MB 3.5 MB/s eta 0:00:30
#    ------ --------------------------------- 19.4/123.0 MB 3.5 MB/s eta 0:00:30
#    ------ --------------------------------- 19.9/123.0 MB 3.5 MB/s eta 0:00:30
#    ------ --------------------------------- 20.7/123.0 MB 3.5 MB/s eta 0:00:30
#    ------ --------------------------------- 21.5/123.0 MB 3.5 MB/s eta 0:00:29
#    ------- -------------------------------- 22.3/123.0 MB 3.5 MB/s eta 0:00:29
#    ------- -------------------------------- 23.1/123.0 MB 3.5 MB/s eta 0:00:29
#    ------- -------------------------------- 23.6/123.0 MB 3.5 MB/s eta 0:00:29
#    ------- -------------------------------- 23.9/123.0 MB 3.5 MB/s eta 0:00:29
#    -------- ------------------------------- 25.2/123.0 MB 3.5 MB/s eta 0:00:28
#    -------- ------------------------------- 26.0/123.0 MB 3.5 MB/s eta 0:00:28
#    -------- ------------------------------- 27.0/123.0 MB 3.5 MB/s eta 0:00:28
#    --------- ------------------------------ 27.8/123.0 MB 3.5 MB/s eta 0:00:27
#    --------- ------------------------------ 28.6/123.0 MB 3.6 MB/s eta 0:00:27
#    --------- ------------------------------ 29.4/123.0 MB 3.6 MB/s eta 0:00:27
#    --------- ------------------------------ 30.1/123.0 MB 3.6 MB/s eta 0:00:26
#    ---------- ----------------------------- 30.9/123.0 MB 3.6 MB/s eta 0:00:26
#    ---------- ----------------------------- 31.2/123.0 MB 3.6 MB/s eta 0:00:26
#    ---------- ----------------------------- 32.0/123.0 MB 3.5 MB/s eta 0:00:26
#    ---------- ----------------------------- 32.8/123.0 MB 3.5 MB/s eta 0:00:26
#    ---------- ----------------------------- 33.6/123.0 MB 3.5 MB/s eta 0:00:26
#    ----------- ---------------------------- 34.3/123.0 MB 3.5 MB/s eta 0:00:26
#    ----------- ---------------------------- 34.9/123.0 MB 3.5 MB/s eta 0:00:25
#    ----------- ---------------------------- 35.7/123.0 MB 3.5 MB/s eta 0:00:25
#    ----------- ---------------------------- 36.7/123.0 MB 3.5 MB/s eta 0:00:25
#    ------------ --------------------------- 37.5/123.0 MB 3.5 MB/s eta 0:00:25
#    ------------ --------------------------- 38.0/123.0 MB 3.5 MB/s eta 0:00:24
#    ------------ --------------------------- 39.1/123.0 MB 3.6 MB/s eta 0:00:24
#    ------------ --------------------------- 39.6/123.0 MB 3.5 MB/s eta 0:00:24
#    ------------- -------------------------- 40.4/123.0 MB 3.6 MB/s eta 0:00:24
#    ------------- -------------------------- 41.2/123.0 MB 3.6 MB/s eta 0:00:23
#    ------------- -------------------------- 41.7/123.0 MB 3.6 MB/s eta 0:00:23
#    ------------- -------------------------- 42.2/123.0 MB 3.6 MB/s eta 0:00:23
#    ------------- -------------------------- 42.7/123.0 MB 3.5 MB/s eta 0:00:23
#    -------------- ------------------------- 43.5/123.0 MB 3.5 MB/s eta 0:00:23
#    -------------- ------------------------- 44.6/123.0 MB 3.5 MB/s eta 0:00:23
#    -------------- ------------------------- 45.4/123.0 MB 3.5 MB/s eta 0:00:22
#    --------------- ------------------------ 46.1/123.0 MB 3.5 MB/s eta 0:00:22
#    --------------- ------------------------ 46.9/123.0 MB 3.5 MB/s eta 0:00:22
#    --------------- ------------------------ 47.7/123.0 MB 3.5 MB/s eta 0:00:22
#    --------------- ------------------------ 48.5/123.0 MB 3.6 MB/s eta 0:00:21
#    ---------------- ----------------------- 49.3/123.0 MB 3.6 MB/s eta 0:00:21
#    ---------------- ----------------------- 50.1/123.0 MB 3.6 MB/s eta 0:00:21
#    ---------------- ----------------------- 50.9/123.0 MB 3.6 MB/s eta 0:00:21
#    ---------------- ----------------------- 51.4/123.0 MB 3.6 MB/s eta 0:00:21
#    ---------------- ----------------------- 52.2/123.0 MB 3.6 MB/s eta 0:00:20
#    ----------------- ---------------------- 53.0/123.0 MB 3.6 MB/s eta 0:00:20
#    ----------------- ---------------------- 53.7/123.0 MB 3.6 MB/s eta 0:00:20
#    ----------------- ---------------------- 54.5/123.0 MB 3.6 MB/s eta 0:00:20
#    ----------------- ---------------------- 55.3/123.0 MB 3.6 MB/s eta 0:00:19
#    ------------------ --------------------- 56.1/123.0 MB 3.6 MB/s eta 0:00:19
#    ------------------ --------------------- 56.9/123.0 MB 3.6 MB/s eta 0:00:19
#    ------------------ --------------------- 57.7/123.0 MB 3.6 MB/s eta 0:00:19
#    ------------------- -------------------- 58.5/123.0 MB 3.6 MB/s eta 0:00:19
#    ------------------- -------------------- 59.2/123.0 MB 3.6 MB/s eta 0:00:18
#    ------------------- -------------------- 60.0/123.0 MB 3.6 MB/s eta 0:00:18
#    ------------------- -------------------- 60.8/123.0 MB 3.6 MB/s eta 0:00:18
#    -------------------- ------------------- 61.6/123.0 MB 3.6 MB/s eta 0:00:18
#    -------------------- ------------------- 62.1/123.0 MB 3.6 MB/s eta 0:00:17
#    -------------------- ------------------- 63.2/123.0 MB 3.6 MB/s eta 0:00:17
#    -------------------- ------------------- 63.7/123.0 MB 3.6 MB/s eta 0:00:17
#    -------------------- ------------------- 64.5/123.0 MB 3.6 MB/s eta 0:00:17
#    --------------------- ------------------ 65.3/123.0 MB 3.6 MB/s eta 0:00:17
#    --------------------- ------------------ 66.1/123.0 MB 3.6 MB/s eta 0:00:16
#    --------------------- ------------------ 66.3/123.0 MB 3.6 MB/s eta 0:00:16
#    --------------------- ------------------ 66.8/123.0 MB 3.5 MB/s eta 0:00:16
#    --------------------- ------------------ 67.6/123.0 MB 3.6 MB/s eta 0:00:16
#    ---------------------- ----------------- 68.4/123.0 MB 3.6 MB/s eta 0:00:16
#    ---------------------- ----------------- 69.2/123.0 MB 3.6 MB/s eta 0:00:16
#    ---------------------- ----------------- 70.3/123.0 MB 3.6 MB/s eta 0:00:15
#    ----------------------- ---------------- 70.8/123.0 MB 3.6 MB/s eta 0:00:15
#    ----------------------- ---------------- 71.6/123.0 MB 3.6 MB/s eta 0:00:15
#    ----------------------- ---------------- 72.4/123.0 MB 3.6 MB/s eta 0:00:15
#    ----------------------- ---------------- 72.9/123.0 MB 3.6 MB/s eta 0:00:15
#    ------------------------ --------------- 73.9/123.0 MB 3.6 MB/s eta 0:00:14
#    ------------------------ --------------- 74.7/123.0 MB 3.6 MB/s eta 0:00:14
#    ------------------------ --------------- 75.5/123.0 MB 3.6 MB/s eta 0:00:14
#    ------------------------ --------------- 76.3/123.0 MB 3.6 MB/s eta 0:00:14
#    ------------------------- -------------- 77.1/123.0 MB 3.6 MB/s eta 0:00:13
#    ------------------------- -------------- 77.9/123.0 MB 3.6 MB/s eta 0:00:13
#    ------------------------- -------------- 78.6/123.0 MB 3.6 MB/s eta 0:00:13
#    ------------------------- -------------- 79.4/123.0 MB 3.6 MB/s eta 0:00:13
#    -------------------------- ------------- 80.5/123.0 MB 3.6 MB/s eta 0:00:12
#    -------------------------- ------------- 81.0/123.0 MB 3.6 MB/s eta 0:00:12
#    -------------------------- ------------- 81.3/123.0 MB 3.6 MB/s eta 0:00:12
#    -------------------------- ------------- 82.6/123.0 MB 3.6 MB/s eta 0:00:12
#    --------------------------- ------------ 83.1/123.0 MB 3.6 MB/s eta 0:00:12
#    --------------------------- ------------ 84.1/123.0 MB 3.6 MB/s eta 0:00:11
#    --------------------------- ------------ 84.9/123.0 MB 3.6 MB/s eta 0:00:11
#    --------------------------- ------------ 85.7/123.0 MB 3.6 MB/s eta 0:00:11
#    ---------------------------- ----------- 86.5/123.0 MB 3.6 MB/s eta 0:00:11
#    ---------------------------- ----------- 87.3/123.0 MB 3.6 MB/s eta 0:00:10
#    ---------------------------- ----------- 88.1/123.0 MB 3.6 MB/s eta 0:00:10
#    ---------------------------- ----------- 88.9/123.0 MB 3.6 MB/s eta 0:00:10
#    ----------------------------- ---------- 89.7/123.0 MB 3.6 MB/s eta 0:00:10
#    ----------------------------- ---------- 90.4/123.0 MB 3.6 MB/s eta 0:00:10
#    ----------------------------- ---------- 90.4/123.0 MB 3.6 MB/s eta 0:00:10
#    ----------------------------- ---------- 91.5/123.0 MB 3.6 MB/s eta 0:00:09
#    ------------------------------ --------- 92.3/123.0 MB 3.6 MB/s eta 0:00:09
#    ------------------------------ --------- 92.8/123.0 MB 3.6 MB/s eta 0:00:09
#    ------------------------------ --------- 93.8/123.0 MB 3.6 MB/s eta 0:00:09
#    ------------------------------ --------- 94.6/123.0 MB 3.6 MB/s eta 0:00:08
#    ------------------------------- -------- 95.4/123.0 MB 3.6 MB/s eta 0:00:08
#    ------------------------------- -------- 96.2/123.0 MB 3.6 MB/s eta 0:00:08
#    ------------------------------- -------- 97.0/123.0 MB 3.6 MB/s eta 0:00:08
#    ------------------------------- -------- 97.8/123.0 MB 3.6 MB/s eta 0:00:07
#    -------------------------------- ------- 98.6/123.0 MB 3.6 MB/s eta 0:00:07
#    -------------------------------- ------- 99.4/123.0 MB 3.6 MB/s eta 0:00:07
#    -------------------------------- ------- 100.4/123.0 MB 3.6 MB/s eta 0:00:07
#    -------------------------------- ------- 100.9/123.0 MB 3.6 MB/s eta 0:00:07
#    --------------------------------- ------ 101.7/123.0 MB 3.6 MB/s eta 0:00:06
#    --------------------------------- ------ 102.5/123.0 MB 3.6 MB/s eta 0:00:06
#    --------------------------------- ------ 103.0/123.0 MB 3.6 MB/s eta 0:00:06
#    --------------------------------- ------ 104.1/123.0 MB 3.6 MB/s eta 0:00:06
#    ---------------------------------- ----- 104.9/123.0 MB 3.6 MB/s eta 0:00:06
#    ---------------------------------- ----- 105.6/123.0 MB 3.6 MB/s eta 0:00:05
#    ---------------------------------- ----- 106.4/123.0 MB 3.6 MB/s eta 0:00:05
#    ---------------------------------- ----- 107.2/123.0 MB 3.6 MB/s eta 0:00:05
#    ----------------------------------- ---- 108.0/123.0 MB 3.6 MB/s eta 0:00:05
#    ----------------------------------- ---- 108.8/123.0 MB 3.6 MB/s eta 0:00:04
#    ----------------------------------- ---- 109.8/123.0 MB 3.6 MB/s eta 0:00:04
#    ----------------------------------- ---- 110.1/123.0 MB 3.6 MB/s eta 0:00:04
#    ------------------------------------ --- 111.1/123.0 MB 3.6 MB/s eta 0:00:04
#    ------------------------------------ --- 111.7/123.0 MB 3.6 MB/s eta 0:00:04
#    ------------------------------------ --- 112.7/123.0 MB 3.6 MB/s eta 0:00:03
#    ------------------------------------ --- 113.2/123.0 MB 3.6 MB/s eta 0:00:03
#    ------------------------------------- -- 114.3/123.0 MB 3.6 MB/s eta 0:00:03
#    ------------------------------------- -- 115.1/123.0 MB 3.6 MB/s eta 0:00:03
#    ------------------------------------- -- 115.6/123.0 MB 3.6 MB/s eta 0:00:03
#    ------------------------------------- -- 116.7/123.0 MB 3.6 MB/s eta 0:00:02
#    -------------------------------------- - 117.4/123.0 MB 3.6 MB/s eta 0:00:02
#    -------------------------------------- - 118.2/123.0 MB 3.6 MB/s eta 0:00:02
#    -------------------------------------- - 119.0/123.0 MB 3.6 MB/s eta 0:00:02
#    -------------------------------------- - 119.8/123.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  120.6/123.0 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  121.4/123.0 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  122.4/123.0 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 123.0/123.0 MB 3.6 MB/s  0:00:34
# Downloading torchvision-0.27.0-cp313-cp313-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.1 MB 4.0 MB/s eta 0:00:01
#    --------------- ------------------------ 1.6/4.1 MB 3.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.4/4.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 3.8 MB/s  0:00:01
# Installing collected packages: torch, torchvision
#
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    ---------------------------------------- 2/2 [torchvision]
#
# Successfully installed torch-2.12.0 torchvision-0.27.0

# %%
import sys
# !{sys.executable} -m pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.12.0-cp310-cp310-win_amd64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading torchvision-0.27.0-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.29.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\admin\.conda\envs\segenv\lib\site-packages (from torch) (4.15.0)
# Collecting setuptools<82 (from torch)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\admin\.conda\envs\segenv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\admin\.conda\envs\segenv\lib\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\admin\.conda\envs\segenv\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\admin\.conda\envs\segenv\lib\site-packages (from torchvision) (12.2.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\.conda\envs\segenv\lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading torch-2.12.0-cp310-cp310-win_amd64.whl (122.9 MB)
#    ---------------------------------------- 0.0/122.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/122.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/122.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/122.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/122.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/122.9 MB 645.7 kB/s eta 0:03:10
#    ---------------------------------------- 0.5/122.9 MB 645.7 kB/s eta 0:03:10
#    ---------------------------------------- 0.8/122.9 MB 658.7 kB/s eta 0:03:06
#    ---------------------------------------- 1.0/122.9 MB 762.8 kB/s eta 0:02:40
#    ---------------------------------------- 1.0/122.9 MB 762.8 kB/s eta 0:02:40
#     --------------------------------------- 1.6/122.9 MB 943.0 kB/s eta 0:02:09
#     --------------------------------------- 1.8/122.9 MB 996.7 kB/s eta 0:02:02
#     --------------------------------------- 2.4/122.9 MB 1.2 MB/s eta 0:01:45
#    - -------------------------------------- 3.1/122.9 MB 1.4 MB/s eta 0:01:28
#    - -------------------------------------- 3.9/122.9 MB 1.6 MB/s eta 0:01:15
#    - -------------------------------------- 5.0/122.9 MB 1.9 MB/s eta 0:01:03
#    -- ------------------------------------- 6.3/122.9 MB 2.2 MB/s eta 0:00:54
#    -- ------------------------------------- 7.3/122.9 MB 2.4 MB/s eta 0:00:48
#    -- ------------------------------------- 8.7/122.9 MB 2.7 MB/s eta 0:00:44
#    --- ------------------------------------ 9.7/122.9 MB 2.8 MB/s eta 0:00:41
#    --- ------------------------------------ 10.5/122.9 MB 2.9 MB/s eta 0:00:39
#    --- ------------------------------------ 11.0/122.9 MB 2.8 MB/s eta 0:00:40
#    --- ------------------------------------ 11.3/122.9 MB 2.8 MB/s eta 0:00:40
#    --- ------------------------------------ 11.8/122.9 MB 2.8 MB/s eta 0:00:40
#    ---- ----------------------------------- 12.6/122.9 MB 2.8 MB/s eta 0:00:40
#    ---- ----------------------------------- 13.9/122.9 MB 2.9 MB/s eta 0:00:38
#    ---- ----------------------------------- 14.7/122.9 MB 3.0 MB/s eta 0:00:37
#    ----- ---------------------------------- 15.5/122.9 MB 3.0 MB/s eta 0:00:36
#    ----- ---------------------------------- 16.3/122.9 MB 3.1 MB/s eta 0:00:35
#    ----- ---------------------------------- 17.3/122.9 MB 3.1 MB/s eta 0:00:35
#    ----- ---------------------------------- 18.4/122.9 MB 3.2 MB/s eta 0:00:33
#    ------ --------------------------------- 18.6/122.9 MB 3.2 MB/s eta 0:00:34
#    ------ --------------------------------- 19.4/122.9 MB 3.1 MB/s eta 0:00:33
#    ------ --------------------------------- 19.7/122.9 MB 3.1 MB/s eta 0:00:33
#    ------ --------------------------------- 20.4/122.9 MB 3.1 MB/s eta 0:00:33
#    ------ --------------------------------- 21.2/122.9 MB 3.1 MB/s eta 0:00:33
#    ------- -------------------------------- 21.8/122.9 MB 3.1 MB/s eta 0:00:33
#    ------- -------------------------------- 22.3/122.9 MB 3.1 MB/s eta 0:00:33
#    ------- -------------------------------- 23.3/122.9 MB 3.1 MB/s eta 0:00:32
#    ------- -------------------------------- 24.1/122.9 MB 3.2 MB/s eta 0:00:32
#    -------- ------------------------------- 24.9/122.9 MB 3.2 MB/s eta 0:00:31
#    -------- ------------------------------- 25.7/122.9 MB 3.2 MB/s eta 0:00:31
#    -------- ------------------------------- 26.2/122.9 MB 3.2 MB/s eta 0:00:31
#    -------- ------------------------------- 26.7/122.9 MB 3.2 MB/s eta 0:00:31
#    -------- ------------------------------- 27.5/122.9 MB 3.2 MB/s eta 0:00:31
#    --------- ------------------------------ 28.3/122.9 MB 3.2 MB/s eta 0:00:30
#    --------- ------------------------------ 29.1/122.9 MB 3.2 MB/s eta 0:00:30
#    --------- ------------------------------ 29.9/122.9 MB 3.2 MB/s eta 0:00:30
#    --------- ------------------------------ 29.9/122.9 MB 3.2 MB/s eta 0:00:30
#    --------- ------------------------------ 30.1/122.9 MB 3.1 MB/s eta 0:00:30
#    --------- ------------------------------ 30.7/122.9 MB 3.1 MB/s eta 0:00:30
#    ---------- ----------------------------- 31.2/122.9 MB 3.1 MB/s eta 0:00:30
#    ---------- ----------------------------- 31.5/122.9 MB 3.1 MB/s eta 0:00:30
#    ---------- ----------------------------- 32.0/122.9 MB 3.0 MB/s eta 0:00:30
#    ---------- ----------------------------- 32.5/122.9 MB 3.0 MB/s eta 0:00:31
#    ---------- ----------------------------- 32.8/122.9 MB 3.0 MB/s eta 0:00:31
#    ---------- ----------------------------- 33.3/122.9 MB 3.0 MB/s eta 0:00:31
#    ----------- ---------------------------- 33.8/122.9 MB 3.0 MB/s eta 0:00:31
#    ----------- ---------------------------- 34.3/122.9 MB 3.0 MB/s eta 0:00:31
#    ----------- ---------------------------- 34.9/122.9 MB 2.9 MB/s eta 0:00:30
#    ----------- ---------------------------- 35.4/122.9 MB 2.9 MB/s eta 0:00:30
#    ----------- ---------------------------- 35.9/122.9 MB 2.9 MB/s eta 0:00:30
#    ----------- ---------------------------- 36.4/122.9 MB 2.9 MB/s eta 0:00:30
#    ------------ --------------------------- 37.0/122.9 MB 2.9 MB/s eta 0:00:30
#    ------------ --------------------------- 37.5/122.9 MB 2.9 MB/s eta 0:00:30
#    ------------ --------------------------- 38.0/122.9 MB 2.9 MB/s eta 0:00:30
#    ------------ --------------------------- 38.5/122.9 MB 2.9 MB/s eta 0:00:30
#    ------------ --------------------------- 39.1/122.9 MB 2.9 MB/s eta 0:00:30
#    ------------ --------------------------- 39.3/122.9 MB 2.9 MB/s eta 0:00:30
#    ------------ --------------------------- 39.6/122.9 MB 2.8 MB/s eta 0:00:30
#    ------------ --------------------------- 39.8/122.9 MB 2.8 MB/s eta 0:00:30
#    ------------- -------------------------- 40.4/122.9 MB 2.8 MB/s eta 0:00:30
#    ------------- -------------------------- 40.9/122.9 MB 2.8 MB/s eta 0:00:30
#    ------------- -------------------------- 41.4/122.9 MB 2.8 MB/s eta 0:00:30
#    ------------- -------------------------- 41.7/122.9 MB 2.8 MB/s eta 0:00:30
#    ------------- -------------------------- 42.2/122.9 MB 2.8 MB/s eta 0:00:30
#    ------------- -------------------------- 42.5/122.9 MB 2.8 MB/s eta 0:00:30
#    ------------- -------------------------- 42.7/122.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 43.3/122.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 43.8/122.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 44.0/122.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 44.3/122.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 44.6/122.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 44.6/122.9 MB 2.7 MB/s eta 0:00:30
#    -------------- ------------------------- 44.8/122.9 MB 2.6 MB/s eta 0:00:30
#    -------------- ------------------------- 44.8/122.9 MB 2.6 MB/s eta 0:00:30
#    -------------- ------------------------- 44.8/122.9 MB 2.6 MB/s eta 0:00:30
#    -------------- ------------------------- 45.1/122.9 MB 2.5 MB/s eta 0:00:31
#    -------------- ------------------------- 45.4/122.9 MB 2.5 MB/s eta 0:00:31
#    -------------- ------------------------- 45.6/122.9 MB 2.5 MB/s eta 0:00:31
#    -------------- ------------------------- 45.9/122.9 MB 2.5 MB/s eta 0:00:31
#    --------------- ------------------------ 46.4/122.9 MB 2.5 MB/s eta 0:00:31
#    --------------- ------------------------ 46.7/122.9 MB 2.5 MB/s eta 0:00:31
#    --------------- ------------------------ 47.2/122.9 MB 2.5 MB/s eta 0:00:31
#    --------------- ------------------------ 47.4/122.9 MB 2.5 MB/s eta 0:00:31
#    --------------- ------------------------ 48.0/122.9 MB 2.5 MB/s eta 0:00:31
#    --------------- ------------------------ 48.2/122.9 MB 2.5 MB/s eta 0:00:31
#    --------------- ------------------------ 48.8/122.9 MB 2.5 MB/s eta 0:00:31
#    --------------- ------------------------ 49.0/122.9 MB 2.4 MB/s eta 0:00:31
#    ---------------- ----------------------- 49.5/122.9 MB 2.4 MB/s eta 0:00:31
#    ---------------- ----------------------- 50.1/122.9 MB 2.4 MB/s eta 0:00:30
#    ---------------- ----------------------- 50.3/122.9 MB 2.4 MB/s eta 0:00:30
#    ---------------- ----------------------- 50.9/122.9 MB 2.4 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.4/122.9 MB 2.4 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.6/122.9 MB 2.4 MB/s eta 0:00:30
#    ---------------- ----------------------- 51.9/122.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 52.4/122.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.0/122.9 MB 2.4 MB/s eta 0:00:30
#    ----------------- ---------------------- 53.5/122.9 MB 2.4 MB/s eta 0:00:29
#    ----------------- ---------------------- 54.0/122.9 MB 2.4 MB/s eta 0:00:29
#    ----------------- ---------------------- 54.5/122.9 MB 2.4 MB/s eta 0:00:29
#    ----------------- ---------------------- 55.1/122.9 MB 2.4 MB/s eta 0:00:29
#    ------------------ --------------------- 55.6/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------ --------------------- 56.1/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------ --------------------- 56.6/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------ --------------------- 56.9/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------ --------------------- 57.1/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------ --------------------- 57.4/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------ --------------------- 57.9/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------ --------------------- 58.2/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------- -------------------- 58.5/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------- -------------------- 59.0/122.9 MB 2.4 MB/s eta 0:00:28
#    ------------------- -------------------- 59.5/122.9 MB 2.4 MB/s eta 0:00:27
#    ------------------- -------------------- 59.5/122.9 MB 2.4 MB/s eta 0:00:27
#    ------------------- -------------------- 59.8/122.9 MB 2.3 MB/s eta 0:00:28
#    ------------------- -------------------- 60.0/122.9 MB 2.3 MB/s eta 0:00:28
#    ------------------- -------------------- 60.3/122.9 MB 2.3 MB/s eta 0:00:28
#    ------------------- -------------------- 60.8/122.9 MB 2.3 MB/s eta 0:00:27
#    ------------------- -------------------- 61.1/122.9 MB 2.3 MB/s eta 0:00:27
#    ------------------- -------------------- 61.3/122.9 MB 2.3 MB/s eta 0:00:27
#    -------------------- ------------------- 61.9/122.9 MB 2.3 MB/s eta 0:00:27
#    -------------------- ------------------- 62.4/122.9 MB 2.3 MB/s eta 0:00:27
#    -------------------- ------------------- 62.9/122.9 MB 2.3 MB/s eta 0:00:27
#    -------------------- ------------------- 63.4/122.9 MB 2.3 MB/s eta 0:00:26
#    -------------------- ------------------- 64.0/122.9 MB 2.3 MB/s eta 0:00:26
#    -------------------- ------------------- 64.2/122.9 MB 2.3 MB/s eta 0:00:26
#    --------------------- ------------------ 64.7/122.9 MB 2.3 MB/s eta 0:00:26
#    --------------------- ------------------ 65.3/122.9 MB 2.3 MB/s eta 0:00:26
#    --------------------- ------------------ 65.8/122.9 MB 2.3 MB/s eta 0:00:25
#    --------------------- ------------------ 66.3/122.9 MB 2.3 MB/s eta 0:00:25
#    --------------------- ------------------ 66.8/122.9 MB 2.3 MB/s eta 0:00:25
#    --------------------- ------------------ 67.4/122.9 MB 2.3 MB/s eta 0:00:25
#    ---------------------- ----------------- 68.2/122.9 MB 2.3 MB/s eta 0:00:24
#    ---------------------- ----------------- 68.7/122.9 MB 2.3 MB/s eta 0:00:24
#    ---------------------- ----------------- 69.2/122.9 MB 2.3 MB/s eta 0:00:24
#    ---------------------- ----------------- 69.7/122.9 MB 2.3 MB/s eta 0:00:23
#    ---------------------- ----------------- 70.3/122.9 MB 2.3 MB/s eta 0:00:23
#    ---------------------- ----------------- 70.5/122.9 MB 2.4 MB/s eta 0:00:23
#    ----------------------- ---------------- 70.8/122.9 MB 2.4 MB/s eta 0:00:23
#    ----------------------- ---------------- 71.6/122.9 MB 2.4 MB/s eta 0:00:22
#    ----------------------- ---------------- 72.1/122.9 MB 2.4 MB/s eta 0:00:22
#    ----------------------- ---------------- 72.9/122.9 MB 2.4 MB/s eta 0:00:22
#    ----------------------- ---------------- 73.1/122.9 MB 2.4 MB/s eta 0:00:21
#    ------------------------ --------------- 73.9/122.9 MB 2.4 MB/s eta 0:00:21
#    ------------------------ --------------- 74.4/122.9 MB 2.4 MB/s eta 0:00:21
#    ------------------------ --------------- 75.0/122.9 MB 2.4 MB/s eta 0:00:21
#    ------------------------ --------------- 75.2/122.9 MB 2.4 MB/s eta 0:00:20
#    ------------------------ --------------- 75.2/122.9 MB 2.4 MB/s eta 0:00:20
#    ------------------------ --------------- 75.8/122.9 MB 2.3 MB/s eta 0:00:21
#    ------------------------ --------------- 76.5/122.9 MB 2.3 MB/s eta 0:00:21
#    ------------------------- -------------- 77.6/122.9 MB 2.3 MB/s eta 0:00:20
#    ------------------------- -------------- 78.4/122.9 MB 2.3 MB/s eta 0:00:20
#    ------------------------- -------------- 79.2/122.9 MB 2.3 MB/s eta 0:00:20
#    -------------------------- ------------- 80.2/122.9 MB 2.3 MB/s eta 0:00:19
#    -------------------------- ------------- 81.0/122.9 MB 2.3 MB/s eta 0:00:19
#    -------------------------- ------------- 81.5/122.9 MB 2.3 MB/s eta 0:00:18
#    -------------------------- ------------- 82.3/122.9 MB 2.3 MB/s eta 0:00:18
#    --------------------------- ------------ 83.4/122.9 MB 2.3 MB/s eta 0:00:18
#    --------------------------- ------------ 84.4/122.9 MB 2.3 MB/s eta 0:00:17
#    --------------------------- ------------ 85.5/122.9 MB 2.3 MB/s eta 0:00:17
#    --------------------------- ------------ 86.0/122.9 MB 2.3 MB/s eta 0:00:16
#    ---------------------------- ----------- 86.8/122.9 MB 2.3 MB/s eta 0:00:16
#    ---------------------------- ----------- 87.8/122.9 MB 2.3 MB/s eta 0:00:16
#    ---------------------------- ----------- 89.1/122.9 MB 2.3 MB/s eta 0:00:15
#    ----------------------------- ---------- 90.2/122.9 MB 2.4 MB/s eta 0:00:14
#    ----------------------------- ---------- 91.5/122.9 MB 2.4 MB/s eta 0:00:14
#    ------------------------------ --------- 92.8/122.9 MB 2.4 MB/s eta 0:00:13
#    ------------------------------ --------- 93.8/122.9 MB 2.4 MB/s eta 0:00:13
#    ------------------------------ --------- 95.2/122.9 MB 2.4 MB/s eta 0:00:12
#    ------------------------------- -------- 96.5/122.9 MB 2.5 MB/s eta 0:00:11
#    ------------------------------- -------- 97.5/122.9 MB 2.5 MB/s eta 0:00:11
#    -------------------------------- ------- 98.6/122.9 MB 2.5 MB/s eta 0:00:10
#    -------------------------------- ------- 99.9/122.9 MB 2.5 MB/s eta 0:00:10
#    --------------------------------- ------ 101.4/122.9 MB 2.5 MB/s eta 0:00:09
#    --------------------------------- ------ 102.5/122.9 MB 2.5 MB/s eta 0:00:09
#    --------------------------------- ------ 103.8/122.9 MB 2.6 MB/s eta 0:00:08
#    ---------------------------------- ----- 105.1/122.9 MB 2.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 106.4/122.9 MB 2.6 MB/s eta 0:00:07
#    ----------------------------------- ---- 107.7/122.9 MB 2.6 MB/s eta 0:00:06
#    ----------------------------------- ---- 109.1/122.9 MB 2.6 MB/s eta 0:00:06
#    ----------------------------------- ---- 109.6/122.9 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------ --- 110.9/122.9 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------ --- 112.2/122.9 MB 2.7 MB/s eta 0:00:04
#    ------------------------------------ --- 113.2/122.9 MB 2.7 MB/s eta 0:00:04
#    ------------------------------------- -- 114.3/122.9 MB 2.8 MB/s eta 0:00:04
#    ------------------------------------- -- 115.1/122.9 MB 2.8 MB/s eta 0:00:03
#    ------------------------------------- -- 115.9/122.9 MB 2.8 MB/s eta 0:00:03
#    -------------------------------------- - 116.9/122.9 MB 2.8 MB/s eta 0:00:03
#    -------------------------------------- - 118.0/122.9 MB 2.8 MB/s eta 0:00:02
#    -------------------------------------- - 119.0/122.9 MB 2.8 MB/s eta 0:00:02
#    ---------------------------------------  120.1/122.9 MB 2.9 MB/s eta 0:00:02
#    ---------------------------------------  121.1/122.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  121.6/122.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  122.7/122.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  122.9/122.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 122.9/122.9 MB 2.9 MB/s  0:00:43
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ----------------------------- ---------- 0.8/1.1 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 2.1 MB/s  0:00:00
# Downloading torchvision-0.27.0-cp310-cp310-win_amd64.whl (3.4 MB)
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.4 MB 3.7 MB/s eta 0:00:01
#    --------------------- ------------------ 1.8/3.4 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------ --- 3.1/3.4 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.4/3.4 MB 4.7 MB/s  0:00:00
# Downloading torchaudio-2.11.0-cp310-cp310-win_amd64.whl (328 kB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.3 MB 5.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.8/6.3 MB 5.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.6/6.3 MB 4.6 MB/s eta 0:00:01
#    --------------------- ------------------ 3.4/6.3 MB 4.2 MB/s eta 0:00:01
#    ------------------------ --------------- 3.9/6.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.3 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 3.5 MB/s  0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 2.5 MB/s  0:00:00
# Downloading filelock-3.29.1-py3-none-any.whl (40 kB)
# Installing collected packages: torchaudio, mpmath, sympy, setuptools, fsspec, filelock, torch, torchvision
#
#    ---------------------------------------- 0/8 [torchaudio]
#    ---------------------------------------- 0/8 [torchaudio]
#    ---------------------------------------- 0/8 [torchaudio]
#    ---------------------------------------- 0/8 [torchaudio]
#    ---------------------------------------- 0/8 [torchaudio]
#    ---------------------------------------- 0/8 [torchaudio]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ----- ---------------------------------- 1/8 [mpmath]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#    ---------- ----------------------------- 2/8 [sympy]
#   Attempting uninstall: setuptools
#    ---------- ----------------------------- 2/8 [sympy]
#     Found existing installation: setuptools 82.0.1
#    ---------- ----------------------------- 2/8 [sympy]
#    --------------- ------------------------ 3/8 [setuptools]
#     Uninstalling setuptools-82.0.1:
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#       Successfully uninstalled setuptools-82.0.1
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    --------------- ------------------------ 3/8 [setuptools]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    ------------------------- -------------- 5/8 [filelock]
#    ------------------------- -------------- 5/8 [filelock]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
# ...
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ------------------------------ --------- 6/8 [torch]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchvision]
#    ---------------------------------------- 8/8 [torchvision]
#
# Successfully installed filelock-3.29.1 fsspec-2026.4.0 mpmath-1.3.0 setuptools-81.0.0 sympy-1.14.0 torch-2.12.0 torchaudio-2.11.0 torchvision-0.27.0
#   WARNING: The script isympy.exe is installed in 'C:\Users\ADMIN\.conda\envs\segenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\ADMIN\.conda\envs\segenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import sys
# !{sys.executable} -m pip show torch
# Out:
# Name: torch
# Version: 2.12.0
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org
# Author:
# Author-email: PyTorch Team <packages@pytorch.org>
# License: BSD-3-Clause
# Location: c:\users\admin\.conda\envs\segenv\lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, setuptools, sympy, typing-extensions
# Required-by: torchvision

# %%
import torch
import torch.nn as nn


class DoubleConv(nn.Module):
    """Two consecutive Conv-BN-ReLU blocks"""

    def __init__(self, in_ch, out_ch):
        super().__init__()

        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),

            nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.block(x)


class UNet(nn.Module):
    """
    Classic U-Net for binary image segmentation
    Input : (B, C, H, W)
    Output: (B, num_classes, H, W)
    """

    def __init__(self, in_channels=1, num_classes=1,
                 features=(64, 128, 256, 512)):
        super().__init__()

        self.downs = nn.ModuleList()
        self.ups = nn.ModuleList()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Encoder
        ch = in_channels
        for f in features:
            self.downs.append(DoubleConv(ch, f))
            ch = f

        # Bottleneck
        self.bottleneck = DoubleConv(features[-1], features[-1] * 2)

        # Decoder
        for f in reversed(features):
            self.ups.append(
                nn.ConvTranspose2d(f * 2, f, kernel_size=2, stride=2)
            )
            self.ups.append(
                DoubleConv(f * 2, f)
            )

        self.final = nn.Conv2d(features[0], num_classes, kernel_size=1)

    def forward(self, x):

        skip_connections = []

        # Encoder
        for down in self.downs:
            x = down(x)
            skip_connections.append(x)
            x = self.pool(x)

        # Bottleneck
        x = self.bottleneck(x)

        skip_connections = skip_connections[::-1]

        # Decoder
        for idx in range(0, len(self.ups), 2):

            x = self.ups[idx](x)

            skip = skip_connections[idx // 2]

            # Handle size mismatch
            if x.shape != skip.shape:
                x = torch.nn.functional.interpolate(
                    x,
                    size=skip.shape[2:]
                )

            x = torch.cat((skip, x), dim=1)

            x = self.ups[idx + 1](x)

        return self.final(x)


# Test
model = UNet(in_channels=1, num_classes=1)

x = torch.randn(1, 1, 256, 256)
y = model(x)

print("Input shape :", x.shape)
print("Output shape:", y.shape)
# Out:
# Input shape : torch.Size([1, 1, 256, 256])
# Output shape: torch.Size([1, 1, 256, 256])

# %%
 def forward(self, x):
            skips = []
            for down in self.downs:
                x = down(x)
                skips.append(x)
                x = self.pool(x)
 
            x = self.bottleneck(x)
            skips = skips[::-1]
 
            for i in range(0, len(self.ups), 2):
                x = self.ups[i](x)
                skip = skips[i // 2]
                if x.shape != skip.shape:
                    x = F.interpolate(x, size=skip.shape[2:])
                x = torch.cat([skip, x], dim=1)
                x = self.ups[i + 1](x)
 
            return self.final(x)

# %%
import numpy as np
import torch
from torch.utils.data import Dataset

class SyntheticSegDataset(Dataset):
    """
    Generates synthetic segmentation images containing
    random elliptical blobs on a noisy background.
    """

    def __init__(
        self,
        n_samples=200,
        img_size=128,
        seed=42
    ):
        super().__init__()

        rng = np.random.default_rng(seed)

        self.images = []
        self.masks = []

        for _ in range(n_samples):

            # Background noise
            img = rng.random(
                (img_size, img_size)
            ).astype(np.float32) * 0.3

            mask = np.zeros(
                (img_size, img_size),
                dtype=np.float32
            )

            # Add 1–3 ellipse objects
            n_blobs = rng.integers(1, 4)

            for _ in range(n_blobs):

                cy, cx = rng.integers(
                    20,
                    img_size - 20,
                    size=2
                )

                ry, rx = rng.integers(
                    8,
                    25,
                    size=2
                )

                y, x = np.ogrid[
                    :img_size,
                    :img_size
                ]

                ellipse = (
                    ((y - cy) / ry) ** 2 +
                    ((x - cx) / rx) ** 2
                ) <= 1

                img[ellipse] += (
                    rng.random() * 0.5 + 0.4
                )

                mask[ellipse] = 1.0

            img = np.clip(img, 0, 1)

            # Add channel dimension
            self.images.append(
                img[None, :, :]
            )

            self.masks.append(
                mask[None, :, :]
            )

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):

        image = torch.tensor(
            self.images[idx],
            dtype=torch.float32
        )

        mask = torch.tensor(
            self.masks[idx],
            dtype=torch.float32
        )

        return image, mask

# %%
    # 4. Training Loop
    # ─────────────────────────────────────────
    def dice_loss(pred, target, smooth=1.0):
        pred   = torch.sigmoid(pred)
        num    = (pred * target).sum(dim=(2, 3))
        den    = pred.sum(dim=(2, 3)) + target.sum(dim=(2, 3))
        return 1 - (2 * num + smooth) / (den + smooth)
 
    def combined_loss(pred, target):
        bce  = F.binary_cross_entropy_with_logits(pred, target)
        dice = dice_loss(pred, target).mean()
        return bce + dice
 
    def train_unet(epochs=10, batch_size=16, lr=1e-3, img_size=128):
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"\n── Training U-Net on {device} ──")
 
        train_ds = SyntheticSegDataset(n_samples=200, img_size=img_size, seed=0)
        val_ds   = SyntheticSegDataset(n_samples=50,  img_size=img_size, seed=99)
        train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_dl   = DataLoader(val_ds,   batch_size=batch_size)
 
        model = UNet(in_channels=1, num_classes=1).to(device)
        opt   = optim.Adam(model.parameters(), lr=lr)
        sched = optim.lr_scheduler.CosineAnnealingLR(opt, T_max=epochs)
 
        history = {"train_loss": [], "val_loss": [], "val_iou": []}
 
        for ep in range(1, epochs + 1):
            # ── Train ──
            model.train()
            t_loss = 0
            for imgs, masks in train_dl:
                imgs, masks = imgs.to(device), masks.to(device)
                opt.zero_grad()
                preds = model(imgs)
                loss  = combined_loss(preds, masks)
                loss.backward()
                opt.step()
                t_loss += loss.item()
            sched.step()
            t_loss /= len(train_dl)

# %%
            # ── Validate ──
           # Validation Phase
import numpy as np
import torch
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader, random_split

# Your dataset object
# Replace SyntheticSegDataset with your dataset class
dataset = SyntheticSegDataset()

# Split dataset into train and validation
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size

train_ds, val_ds = random_split(
    dataset,
    [train_size, val_size],
    generator=torch.Generator().manual_seed(42)
)

# Create DataLoaders
BATCH_SIZE = 8

train_dl = DataLoader(
    train_ds,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0
)

val_dl = DataLoader(
    val_ds,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0
)

print("Training samples:", len(train_ds))
print("Validation samples:", len(val_ds))
# Out:
# Training samples: 160
# Validation samples: 40

# %%
print("dataset" in globals())
print("train_dl" in globals())
print("val_dl" in globals())
# Out:
# True
# True
# True

# %%
  # ── Collect predictions for curves ──
def collect_predictions(model, val_dl, val_ds, history):

    all_probs = []
    all_labels = []

    device = torch.device(
        "cuda" if torch.cuda.is_available() else "cpu"
    )

    model.eval()

    with torch.no_grad():
        for imgs, masks in val_dl:

            imgs = imgs.to(device)

            probs = torch.sigmoid(
                model(imgs)
            ).cpu().numpy().flatten()

            all_probs.extend(probs)
            all_labels.extend(
                masks.cpu().numpy().flatten()
            )

    return (
        model,
        history,
        np.array(all_probs),
        np.array(all_labels),
        val_ds,
        device
    )

# %%
# 5. Simulation Fallback (no PyTorch)
# ─────────────────────────────────────────────
def simulate_predictions(n=10000, seed=7):
    """
    Simulate realistic segmentation probabilities for
    ROC / PR demo without any deep learning framework.
    """
    rng = np.random.default_rng(seed)
    labels = rng.integers(0, 2, n)
    # Model scores: foreground pixels score higher on average
    probs  = np.where(
        labels == 1,
        rng.beta(5, 2, n),   # foreground: skewed high
        rng.beta(2, 5, n),   # background: skewed low
    )
    return probs, labels

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\admin\.conda\envs\segenv\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\admin\.conda\envs\segenv\lib\site-packages (from scikit-learn) (1.15.3)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.9 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/8.9 MB 1.7 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.9 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.1/8.9 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/8.9 MB 2.1 MB/s eta 0:00:03
#    --------------- ------------------------ 3.4/8.9 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 4.5/8.9 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 5.5/8.9 MB 2.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.6/8.9 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.9/8.9 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 3.5 MB/s  0:00:02
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 threadpoolctl-3.6.0

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
# 6. Visualization



import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from matplotlib.colors import LinearSegmentedColormap

from sklearn.metrics import (
    roc_curve,
    auc,
    precision_recall_curve,
    average_precision_score
)

import torch

# ============================================================
# Color Theme
# ============================================================

PALETTE = {
    "bg": "#0d0d14",
    "panel": "#13131f",
    "border": "#2a2a3d",
    "teal": "#00e5c3",
    "purple": "#9b5de5",
    "pink": "#f72585",
    "yellow": "#f9c74f",
    "white": "#e8e8f0",
    "grey": "#555570",
}

seg_cmap = LinearSegmentedColormap.from_list(
    "seg",
    ["#0d0d14", "#00e5c3"],
    N=256
)

# ============================================================
# Styling Function
# ============================================================

def style_ax(ax, title=""):

    ax.set_facecolor(PALETTE["panel"])

    for sp in ax.spines.values():
        sp.set_edgecolor(PALETTE["border"])

    ax.tick_params(
        colors=PALETTE["grey"],
        labelsize=9
    )

    ax.xaxis.label.set_color(PALETTE["white"])
    ax.yaxis.label.set_color(PALETTE["white"])

    if title:
        ax.set_title(
            title,
            color=PALETTE["white"],
            fontsize=11,
            fontweight="bold",
            pad=8
        )

    ax.grid(
        color=PALETTE["border"],
        linewidth=0.5,
        linestyle="--",
        alpha=0.6
    )

# ============================================================
# ROC Curve
# ============================================================

def plot_roc(ax, labels, probs):

    fpr, tpr, _ = roc_curve(labels, probs)
    roc_auc = auc(fpr, tpr)

    ax.plot(
        fpr,
        tpr,
        color=PALETTE["teal"],
        lw=2,
        label=f"AUC = {roc_auc:.4f}"
    )

    ax.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        color=PALETTE["grey"]
    )

    ax.fill_between(
        fpr,
        tpr,
        alpha=0.10,
        color=PALETTE["teal"]
    )

    ax.set_xlabel("False Positive Rate")
    ax.set_ylabel("True Positive Rate")

    style_ax(ax, "ROC Curve")

    leg = ax.legend(framealpha=0)

    for txt in leg.get_texts():
        txt.set_color(PALETTE["white"])

    return roc_auc

# ============================================================
# Precision Recall Curve
# ============================================================

def plot_pr(ax, labels, probs):

    precision, recall, _ = precision_recall_curve(
        labels,
        probs
    )

    ap = average_precision_score(
        labels,
        probs
    )

    baseline = labels.mean()

    ax.plot(
        recall,
        precision,
        color=PALETTE["purple"],
        lw=2,
        label=f"AP = {ap:.4f}"
    )

    ax.axhline(
        baseline,
        linestyle="--",
        color=PALETTE["grey"],
        label=f"Baseline = {baseline:.3f}"
    )

    ax.fill_between(
        recall,
        precision,
        alpha=0.10,
        color=PALETTE["purple"]
    )

    ax.set_xlabel("Recall")
    ax.set_ylabel("Precision")

    style_ax(ax, "Precision-Recall Curve")

    leg = ax.legend(framealpha=0)

    for txt in leg.get_texts():
        txt.set_color(PALETTE["white"])

    return ap

# ============================================================
# Training History
# ============================================================

def plot_history(ax_loss, ax_iou, history):

    epochs = range(
        1,
        len(history["train_loss"]) + 1
    )

    ax_loss.plot(
        epochs,
        history["train_loss"],
        lw=2,
        color=PALETTE["pink"],
        label="Train"
    )

    ax_loss.plot(
        epochs,
        history["val_loss"],
        lw=2,
        linestyle="--",
        color=PALETTE["yellow"],
        label="Validation"
    )

    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Loss")

    style_ax(ax_loss, "Loss Curve")

    leg = ax_loss.legend(framealpha=0)

    for txt in leg.get_texts():
        txt.set_color(PALETTE["white"])

    ax_iou.plot(
        epochs,
        history["val_iou"],
        color=PALETTE["teal"],
        lw=2,
        marker="o"
    )

    ax_iou.set_xlabel("Epoch")
    ax_iou.set_ylabel("IoU")

    style_ax(ax_iou, "Validation IoU")

# ============================================================
# Predictions
# ============================================================

def plot_predictions(axes, val_ds, model, device):

    model.eval()

    indices = [
        0,
        len(val_ds)//2,
        len(val_ds)-1
    ]

    with torch.no_grad():

        for col, idx in enumerate(indices):

            img, mask = val_ds[idx]

            pred = torch.sigmoid(
                model(
                    img.unsqueeze(0).to(device)
                )
            )

            pred = pred.squeeze().cpu().numpy()

            img_np = img.squeeze().numpy()
            mask_np = mask.squeeze().numpy()

            axes[0][col].imshow(
                img_np,
                cmap="gray"
            )

            axes[1][col].imshow(
                mask_np,
                cmap=seg_cmap
            )

            axes[2][col].imshow(
                pred,
                cmap=seg_cmap
            )

            for r in range(3):
                axes[r][col].axis("off")

# ============================================================
# Main Visualization
# ============================================================

def build_figure_torch(
    probs,
    labels,
    history,
    val_ds,
    model,
    device
):

    fig = plt.figure(
        figsize=(20, 14),
        facecolor=PALETTE["bg"]
    )

    gs_top = gridspec.GridSpec(
        2,
        2,
        figure=fig,
        left=0.06,
        right=0.98,
        top=0.95,
        bottom=0.52,
        wspace=0.32,
        hspace=0.45
    )

    gs_bot = gridspec.GridSpec(
        3,
        3,
        figure= fig,
        left=0.06,
        right=0.98,
        top=0.46,
        bottom=0.04,
        wspace=0.05,
        hspace=0.05
    )

    ax_roc = fig.add_subplot(gs_top[0, 0])
    ax_pr = fig.add_subplot(gs_top[0, 1])
    ax_loss = fig.add_subplot(gs_top[1, 0])
    ax_iou = fig.add_subplot(gs_top[1, 1])

    roc_auc = plot_roc(
        ax_roc,
        labels,
        probs
    )

    ap = plot_pr(
        ax_pr,
        labels,
        probs
    )

    plot_history(
        ax_loss,
        ax_iou,
        history
    )

    axes = [
        [fig.add_subplot(gs_bot[r, c]) for c in range(3)]
        for r in range(3)
    ]

    plot_predictions(
        axes,
        val_ds,
        model,
        device
    )

    fig.suptitle(
        "U-Net Segmentation Results",
        color=PALETTE["white"],
        fontsize=16,
        fontweight="bold"
    )

    plt.savefig(
        "unet_segmentation_results.png",
        dpi=150,
        bbox_inches="tight",
        facecolor=PALETTE["bg"]
    )

    plt.show()

    print(f"ROC AUC: {roc_auc:.4f}")
    print(f"Average Precision: {ap:.4f}")

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(12, 10))

gs_bot = gridspec.GridSpec(
    3, 3,
    figure=fig,
    wspace=0.05,
    hspace=0.05
)
# Sample predictions grid
pred_axes = []

for r in range(3):
    row = []

    for c in range(3):
        ax = fig.add_subplot(gs_bot[r, c])
        ax.set_facecolor(PALETTE["panel"])
        row.append(ax)

    pred_axes.append(row)

plot_predictions(
    pred_axes,
    val_ds,
    model,
    device
)

plt.show()

# %%
# Column headers
for c, lbl in enumerate(
    ["Sample A", "Sample B", "Sample C"]
):
    pred_axes[0][c].set_title(
        lbl,
        color=PALETTE["grey"],
        fontsize=9,
        pad=4
    )

fig.suptitle(
    "U-Net Image Segmentation – Full Evaluation Dashboard",
    color=PALETTE["white"],
    fontsize=15,
    fontweight="bold"
)

# Save in current notebook folder
out = "segmentation_dashboard.png"

plt.savefig(
    out,
    dpi=150,
    bbox_inches="tight",
    facecolor=PALETTE["bg"]
)

print(f"\nSaved → {out}")

if "history" in globals():
    print(
        f"Final Val IoU : "
        f"{history['val_iou'][-1]:.4f}"
    )

if "roc_auc" in globals():
    print(f"ROC AUC       : {roc_auc:.4f}")

if "ap" in globals():
    print(f"Avg Precision : {ap:.4f}")

plt.show()
# Out:
# Saved → segmentation_dashboard.png

# %%
# ─────────────────────────────────────────────
# 7. Main
# ============================================================
# MAIN EXECUTION

# ============================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np

from torch.utils.data import Dataset, DataLoader, random_split

try:
    TORCH_AVAILABLE = True
except Exception:
    TORCH_AVAILABLE = False


def check_requirements():
    required_functions = [
        "train_unet",
        "build_figure_torch"
    ]

    missing = []

    for fn in required_functions:
        if fn not in globals():
            missing.append(fn)

    if missing:
        print("\nMissing functions:")
        for fn in missing:
            print(" -", fn)
        return False

    return True


if __name__ == "__main__":

    print("=" * 60)
    print("U-NET IMAGE SEGMENTATION")
    print("=" * 60)

    if not TORCH_AVAILABLE:
        print("\nPyTorch is not available.")
        raise SystemExit

    if not check_requirements():
        raise SystemExit

    device = torch.device(
        "cuda" if torch.cuda.is_available() else "cpu"
    )

    print(f"\nUsing device: {device}")

    try:

        model, history, probs, labels, val_ds, device = train_unet(
            epochs=15,
            batch_size=16,
            lr=1e-3,
            img_size=128
        )

        print("\nTraining completed successfully.")

        build_figure_torch(
            probs,
            labels,
            history,
            val_ds,
            model,
            device
        )

        print("\nEvaluation dashboard generated.")

    except Exception as e:

        print("\nTraining failed.")
        print("Error:", e)

    print("\nDone.")
# Out:
# ============================================================
# U-NET IMAGE SEGMENTATION
# ============================================================
#
# Using device: cpu
#
# ── Training U-Net on cpu ──
